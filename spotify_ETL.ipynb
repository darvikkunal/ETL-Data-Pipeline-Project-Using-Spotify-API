# %%
pip install spotipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Authentication
client_credentials_manager = SpotifyClientCredentials(client_id="775909f0dc4d429f951f544499cd0f86", client_secret="df20b560e9d64da79d3b64e53bc65824")

# %%
#Authorization
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
#Latest Telugu Songs [automatically keeps changing when new songs adds to spotify]
playlist_link = "https://open.spotify.com/playlist/37i9dQZF1DWWwrjLPC16W7"

# %%
#Extracting the URI ID from playlist link
playlist_URI = playlist_link.split('/')[-1]
playlist_URI
# Out:
# '37i9dQZF1DWWwrjLPC16W7'

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data['items'][0]['track']['album']['id']
# Out:
# '6pljUGFM7d4Gq99fn6jrgb'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Raa Macha Macha (From "Game Changer") (Telugu)'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2024-09-30'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/6pljUGFM7d4Gq99fn6jrgb'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id': album_id, 'album_name': album_name, 'album_release_date': album_release_date , 'album_total_tracks': album_total_tracks , 'album_url': album_url}
    print(album_element)
    album_list.append(album_element)
# Out:
# {'album_id': '6pljUGFM7d4Gq99fn6jrgb', 'album_name': 'Raa Macha Macha (From "Game Changer") (Telugu)', 'album_release_date': '2024-09-30', 'album_total_tracks': 1, 'album_url': 'https://open.spotify.com/album/6pljUGFM7d4Gq99fn6jrgb'}
# {'album_id': '2x3tNtqwjjGuXliVM7fzQi', 'album_name': 'Daavudi (From "Devara Part 1") [TELUGU]', 'album_release_date': '2024-09-04', 'album_total_tracks': 1, 'album_url': 'https://open.spotify.com/album/2x3tNtqwjjGuXliVM7fzQi'}
# {'album_id': '5K8pnyAMPHrcjkeUGWBCA9', 'album_name': 'Nallanchu Thellacheera (From "Mr. Bachchan")', 'album_release_date': '2024-08-12', 'album_total_tracks': 1, 'album_url': 'https://open.spotify.com/album/5K8pnyAMPHrcjkeUGWBCA9'}
# {'album_id': '7JKtsiV6oNgr4wGMHpAW0Q', 'album_name': 'Saripodhaa Sanivaaram - Original Motion Picture Soundtrack', 'album_release_date': '2024-08-28', 'album_total_tracks': 12, 'album_url': 'https://open.spotify.com/album/7JKtsiV6oNgr4wGMHpAW0Q'}
# ...

# %%
album_list
# Out:
# [{'album_id': '6pljUGFM7d4Gq99fn6jrgb',
#   'album_name': 'Raa Macha Macha (From "Game Changer") (Telugu)',
#   'album_release_date': '2024-09-30',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/6pljUGFM7d4Gq99fn6jrgb'},
#  {'album_id': '2x3tNtqwjjGuXliVM7fzQi',
#   'album_name': 'Daavudi (From "Devara Part 1") [TELUGU]',
#   'album_release_date': '2024-09-04',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/2x3tNtqwjjGuXliVM7fzQi'},
#  {'album_id': '5K8pnyAMPHrcjkeUGWBCA9',
#   'album_name': 'Nallanchu Thellacheera (From "Mr. Bachchan")',
#   'album_release_date': '2024-08-12',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/5K8pnyAMPHrcjkeUGWBCA9'},
#  {'album_id': '7JKtsiV6oNgr4wGMHpAW0Q',
#   'album_name': 'Saripodhaa Sanivaaram - Original Motion Picture Soundtrack',
#   'album_release_date': '2024-08-28',
#   'album_total_tracks': 12,
# ...

# %%
data['items'][0]
# Out:
# {'added_at': '2024-09-30T11:54:17Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': 'https://p.scdn.co/mp3-preview/b9e882d1d6f7fb6415ff6cd05a0adf7872a5dd21?cid=775909f0dc4d429f951f544499cd0f86',
#   'available_markets': ['IN'],
#   'explicit': False,
#   'type': 'track',
#   'episode': False,
#   'track': True,
#   'album': {'available_markets': ['IN'],
#    'type': 'album',
#    'album_type': 'single',
#    'href': 'https://api.spotify.com/v1/albums/6pljUGFM7d4Gq99fn6jrgb',
#    'id': '6pljUGFM7d4Gq99fn6jrgb',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27302acb2ef81d59edc891cbac0',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0202acb2ef81d59edc891cbac0',
# ...

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_dict={'artist_id': artist['id'], 'artist_name': artist['name'], 'artist_URL' : artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '2FgHPfRprDaylrSRVf1UlN',
#   'artist_name': 'Thaman S',
#   'artist_URL': 'https://api.spotify.com/v1/artists/2FgHPfRprDaylrSRVf1UlN'},
#  {'artist_id': '5wE0KHIPasAq9oKW3PkDpq',
#   'artist_name': 'Anantha Sriram',
#   'artist_URL': 'https://api.spotify.com/v1/artists/5wE0KHIPasAq9oKW3PkDpq'},
#  {'artist_id': '4kq8z3vydHjPDggxb16ErB',
#   'artist_name': 'Nakash Aziz',
#   'artist_URL': 'https://api.spotify.com/v1/artists/4kq8z3vydHjPDggxb16ErB'},
#  {'artist_id': '4kq8z3vydHjPDggxb16ErB',
#   'artist_name': 'Nakash Aziz',
#   'artist_URL': 'https://api.spotify.com/v1/artists/4kq8z3vydHjPDggxb16ErB'},
#  {'artist_id': '4mRPyvdSBxARQIFeXXM13s',
#   'artist_name': 'AKASA',
#   'artist_URL': 'https://api.spotify.com/v1/artists/4mRPyvdSBxARQIFeXXM13s'},
#  {'artist_id': '4zCH9qm4R2DADamUHMCa6O',
#   'artist_name': 'Anirudh Ravichander',
#   'artist_URL': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O'},
#  {'artist_id': '2bfyLSCw72lQ5qoD8cdVBB',
# ...
